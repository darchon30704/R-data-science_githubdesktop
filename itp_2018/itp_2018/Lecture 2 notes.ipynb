# %%
print (type(3),3)
print (type(2.5), 2.5)
print (type('apples'), apples)
# Out:
# <class 'int'> 3
# <class 'float'> 2.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4035dd79f1ff> in <module>()
#       1 print (type(3),3)
#       2 print (type(2.5), 2.5)
# ----> 3 print (type('apples'), apples)
#
# NameError: name 'apples' is not defined

# %%
print("'Ban' + 'ana' = ", 'Ban' + 'ana')
print("'Ba' * 5 = ", 'Ba' * 5)
# Out:
# 'Ban' + 'ana' =  Banana
# 'Ba' * 5 =  BaBaBaBaBa

# %%
print("'Banana'.upper() = ", 'Banana'.upper())
print("'banana'.isupper() = ", 'banana'.isupper())
print("'BANANA'.isupper() = ", 'BANANA'.isupper())
print("'124'.isdigit() = ", '124'.isdigit()) # note that this is a string
print('124'.isdigit())
print("'Banana'.swapcase() = ", 'Banana'.swapcase())
# Out:
# 'Banana'.upper() =  BANANA
# 'banana'.isupper() =  False
# 'BANANA'.isupper() =  True
# '124'.isdigit() =  True
# True
# 'Banana'.swapcase() =  bANANA

# %%
print (type(3), 3) # integer
print (type(2.5), 2.5) # float
print (type('apples'), 'apples') # string
print (type(True), True) # boolean
print (type('3'), '3') # string
print (type('2.5'), '2.5') # string
# Out:
# <class 'int'> 3
# <class 'float'> 2.5
# <class 'str'> apples
# <class 'bool'> True
# <class 'str'> 3
# <class 'str'> 2.5

# %%
help ('banana'.upper)
# Out:
# Help on built-in function upper:
#
# upper(...) method of builtins.str instance
#     S.upper() -> str
#
#     Return a copy of S converted to uppercase.

# %%
# dir(0)
# dir('string')
# dir(0.1)

# %%
dir(0)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
int_one = 5
int_two = 10
result = int_one + int_two
print (result)
# Out:
# 15

# %%
print(result)
result = result + 5
print(result)
# Out:
# 15
# 20

# %%
animal = "dog"
print (id(animal), animal)
animal = animal + 'a'
print (id(animal), animal) #animal is a new object, previous one is delete
# Out:
# 4456015440 dog
# 4456452648 doga

# %%
numbers = [1,2,3] # this is a list ( more on this later)
print (id(numbers), numbers)
numbers.append(4)
print (id(numbers), numbers) #numbers object is the same
# Out:
# 4455897160 [1, 2, 3]
# 4455897160 [1, 2, 3, 4]
